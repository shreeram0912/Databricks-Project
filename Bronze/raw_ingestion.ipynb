# %%
# Azure SQL Database connection parameters
jdbc_hostname = "sqlserver-databricksproject.database.windows.net"
jdbc_port = 1433
jdbc_database = "database-databricksproject"
jdbc_username = "ram"
jdbc_password = "Home@123"

jdbc_url = f"jdbc:sqlserver://{jdbc_hostname}:{jdbc_port};database={jdbc_database};encrypt=true;trustServerCertificate=false;hostNameInCertificate=*.database.windows.net;loginTimeout=30;"

connection_properties = {
    "user": jdbc_username,
    "password": jdbc_password,
    "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver"
}

# %%
# Read table from Azure SQL Database = historical_orders
df_historical_orders = spark.read.jdbc(
    url=jdbc_url,
    table="dbo.historical_orders",
    properties=connection_properties
)

# %%
# Read table from Azure SQL Database = customers
df_Customers = spark.read.jdbc(
    url=jdbc_url,
    table="dbo.customers",
    properties=connection_properties
)

# %%
# Read table from Azure SQL Database = reviews
df_reviews = spark.read.jdbc(
    url=jdbc_url,
    table="dbo.reviews",
    properties=connection_properties
)

# %%
# Read table from Azure SQL Database = menu_items
df_menu_items = spark.read.jdbc(
    url=jdbc_url,
    table="dbo.menu_items",
    properties=connection_properties
)

# %%
# Read table from Azure SQL Database = restaurants
df_restaurants = spark.read.jdbc(
    url=jdbc_url,
    table="dbo.restaurants",
    properties=connection_properties
)

# %%
# Write table from Azure SQL Database to databricks catalog in delta format = restaurants
df_restaurants.write \
  .format("delta") \
  .mode("overwrite") \
  .option("overwriteSchema", "true") \
  .saveAsTable("ws_dbxproject_catalog.01_bronze.restaurants")

# %%
# Write table from Azure SQL Database to databricks catalog in delta format = historical orders

df_historical_orders.write \
  .format("delta") \
  .mode("overwrite") \
  .option("overwriteSchema", "true") \
  .saveAsTable("ws_dbxproject_catalog.01_bronze.historical_orders")

# %%
# Write table from Azure SQL Database to databricks catalog in delta format = customers

df_Customers.write \
  .format("delta") \
  .mode("overwrite") \
  .option("overwriteSchema", "true") \
  .saveAsTable("ws_dbxproject_catalog.01_bronze.customers")

# %%
# Write table from Azure SQL Database to databricks catalog in delta format = reviews

df_reviews.write \
  .format("delta") \
  .mode("overwrite") \
  .option("overwriteSchema", "true") \
  .saveAsTable("ws_dbxproject_catalog.01_bronze.reviews")

# %%
# Write table from Azure SQL Database to databricks catalog in delta format = menu_items

df_menu_items.write \
  .format("delta") \
  .mode("overwrite") \
  .option("overwriteSchema", "true") \
  .saveAsTable("ws_dbxproject_catalog.01_bronze.menu_items")
